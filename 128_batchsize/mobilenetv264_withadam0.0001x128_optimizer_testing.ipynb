# %%
import sys
import os
import argparse

# Time
import time
import datetime

# Numerical Data
import random
import numpy as np 
import pandas as pd

# Tools
import shutil
from glob import glob
from tqdm import tqdm
import gc

# NLP
import re

# Preprocessing
from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import shuffle

# Model Selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# Machine Learning Models
from sklearn import svm
from sklearn.svm import LinearSVC, SVC

# Evaluation Metrics
from sklearn import metrics 
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, roc_auc_score

#tesnorflow
import tensorflow as tf
from tensorflow import keras
# Deep Learning - Keras -  Preprocessing
from keras.preprocessing.image import ImageDataGenerator

# Deep Learning - Keras - Model

import keras
from keras import models
from keras.models import Model
from keras.models import Sequential

# Deep Learning - Keras - Layers

from tensorflow.keras.layers  import Convolution1D, concatenate, SpatialDropout1D, GlobalMaxPool1D, GlobalAvgPool1D, Embedding, Conv2D, SeparableConv1D, Add, BatchNormalization, Activation, GlobalAveragePooling2D, LeakyReLU, Flatten
from tensorflow.keras.layers import Dense, Input, Dropout, MaxPooling2D, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, \
    Lambda, Multiply, LSTM, Bidirectional, PReLU, MaxPooling1D, DepthwiseConv2D


# Deep Learning - Keras - Pretrained Models
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications.inception_v3 import InceptionV3

# Deep Learning - Keras - Model Parameters and Evaluation Metrics

from keras import optimizers
from tensorflow.keras.optimizers import Adam, SGD , RMSprop
from keras.losses import mae, sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# Deep Learning - Keras - Visualisation

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

# from keras.wrappers.scikit_learn import KerasClassifier

from keras import backend as K

# Deep Learning - TensorFlow

import tensorflow as tf

# Graph/ Visualization

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.image as mpimg
import seaborn as sns
from mlxtend.plotting import plot_confusion_matrix

# Image

import cv2
from PIL import Image
from IPython.display import display

# np.random.seed(42)

# %matplotlib inline

# %%
from tensorflow.keras.models import load_model
 
# load model
model = load_model('C:/DUAEFATIMA/batchsizes_experiments/128_batchsize/mobilenetv2_128.h5')
# summarize model.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 32)                40992
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 2,299,589
# Trainable params: 2,265,477
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
y_test_1=[]
test_path_1='C:/DUAEFATIMA/test_merge'

for i in os.listdir(test_path_1):
  #print(i)
  if "A" in i:
    y_test_1.append(0)

#print(y_test)
for i in os.listdir(test_path_1):
  #print(i)
  if "B" in i:
    y_test_1.append(1)
#print(y_test)
for i in os.listdir(test_path_1):
  #print(i)
  if "C" in i:
    y_test_1.append(2)
#print(y_test)
for i in os.listdir(test_path_1):
  #print(i)
  if "D" in i:
    y_test_1.append(3)
#print(y_test)
for i in os.listdir(test_path_1):
  #print(i)
  if "E" in i:
    y_test_1.append(4)
#print(y_test_1)
print(len(y_test_1))
###############################
# Out:
# 4923

# %%
#samreen editt

start = datetime.datetime.now()

y_pred_1=[]
ds_eye_dir = "C:/DUAEFATIMA/experiments/eyePACS/eyepacs_augmented"
#Generating a dataset
ds_eye = tf.keras.preprocessing.image_dataset_from_directory(ds_eye_dir)
test_path_1='C:/DUAEFATIMA/test_merge'
for i in os.listdir(test_path_1):
  print(i)
  img=image.load_img(test_path_1+'//'+i,target_size=(224,224))
  #img = tf.keras.utils.load_img(image_path, target_size=(224,224))
  img = np.array(img)
  img = img / 255.0
  img = img.reshape(1,224,224,3)
  label = model.predict(img)
  # print("Predicted score",label)
   #print("Predicted Clas, ls (0 - Cars , 1- Planes): ", label[1][1])
  p=np.argmax(label)
  print("Predicted ",ds_eye.class_names[p])
  #print([p])
  y_pred_1.append(p)


end = datetime.datetime.now()
elapsed= end-start
print ("Time: ", elapsed)
print(len(y_pred_1))
# Out:
# Found 49006 files belonging to 5 classes.
# classA (1).jpeg
# 1/1 [==============================] - 7s 7s/step
# Predicted  level_0
# classA (10).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_0
# classA
jpeg
# 1/1 [==============================] - 0s 60ms/step
# Predicted  level_4
# classE (808).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (809).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (81).jpeg
# 1/1 [==============================] - 0s 75ms/step
# Predicted  level_4
# classE (810).jpeg
# 1/1 [==============================] - 0s 50ms/step
# Predicted  level_4
# classE (811).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (812).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (813).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (814).jpeg
# 1/1 [==============================] - 0s 65ms/step
# Predicted  level_4
# classE (815).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (816).jpeg
# 1/1 [==============================] - 0s 72ms/step
# Predicted  level_4
# classE (817).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (818).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (819).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (82).jpeg
# 1/1 [==============================] - 0s 65ms/step
# Predicted  level_4
# classE (820).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (821).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (822).jpeg
# 1/1 [==============================] - 0s 64ms/step
# Predicted  level_4
# classE (823).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (824).jpeg
# 1/1 [==============================] - 0s 47ms/step
# Predicted  level_4
# classE (825).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (826).jpeg
# 1/1 [==============================] - 0s 64ms/step
# Predicted  level_4
# classE (827).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (828).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (829).jpeg
# 1/1 [==============================] - 0s 67ms/step
# Predicted  level_4
# classE (83).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (830).jpeg
# 1/1 [==============================] - 0s 65ms/step
# Predicted  level_4
# classE (831).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (832).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (833).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (834).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (835).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (836).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (837).jpeg
# 1/1 [==============================] - 0s 62ms/step
# Predicted  level_4
# classE (838).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (839).jpeg
# 1/1 [==============================] - 0s 68ms/step
# Predicted  level_4
# classE (84).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (840).jpeg
# 1/1 [==============================] - 0s 48ms/step
# Predicted  level_4
# classE (841).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (842).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (843).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (844).jpeg
# 1/1 [==============================] - 0s 48ms/step
# Predicted  level_4
# classE (845).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (846).jpeg
# 1/1 [==============================] - 0s 67ms/step
# Predicted  level_0
# classE (847).jpeg
# 1/1 [==============================] - 0s 64ms/step
# Predicted  level_4
# classE (848).jpeg
# 1/1 [==============================] - 0s 62ms/step
# Predicted  level_4
# classE (849).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (85).jpeg
# 1/1 [==============================] - 0s 50ms/step
# Predicted  level_4
# classE (850).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (851).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (852).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (853).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (854).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (855).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (856).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (857).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (858).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (859).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (86).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (860).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (861).jpeg
# 1/1 [==============================] - 0s 58ms/step
# Predicted  level_4
# classE (862).jpeg
# 1/1 [==============================] - 0s 58ms/step
# Predicted  level_4
# classE (863).jpeg
# 1/1 [==============================] - 0s 60ms/step
# Predicted  level_4
# classE (864).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (865).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (866).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (867).jpeg
# 1/1 [==============================] - 0s 67ms/step
# Predicted  level_4
# classE (868).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (869).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (87).jpeg
# 1/1 [==============================] - 0s 66ms/step
# Predicted  level_4
# classE (870).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (871).jpeg
# 1/1 [==============================] - 0s 70ms/step
# Predicted  level_4
# classE (872).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (873).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (874).jpeg
# 1/1 [==============================] - 0s 73ms/step
# Predicted  level_4
# classE (875).jpeg
# 1/1 [==============================] - 0s 62ms/step
# Predicted  level_4
# classE (876).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (877).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (878).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (879).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (88).jpeg
# 1/1 [==============================] - 0s 58ms/step
# Predicted  level_4
# classE (880).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (881).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (882).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (883).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (884).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (885).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (886).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (887).jpeg
# 1/1 [==============================] - 0s 50ms/step
# Predicted  level_4
# classE (888).jpeg
# 1/1 [==============================] - 0s 56ms/step
# Predicted  level_4
# classE (889).jpeg
# 1/1 [==============================] - 0s 71ms/step
# Predicted  level_4
# classE (89).jpeg
# 1/1 [==============================] - 0s 48ms/step
# Predicted  level_4
# classE (890).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (891).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (892).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (893).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (894).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (895).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (896).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (897).jpeg
# 1/1 [==============================] - 0s 51ms/step
# Predicted  level_4
# classE (898).jpeg
# 1/1 [==============================] - 0s 57ms/step
# Predicted  level_4
# classE (899).jpeg
# 1/1 [==============================] - 0s 69ms/step
# Predicted  level_4
# classE (9).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (90).jpeg
# 1/1 [==============================] - 0s 55ms/step
# Predicted  level_4
# classE (900).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (901).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (902).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (903).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (904).jpeg
# 1/1 [==============================] - 0s 59ms/step
# Predicted  level_4
# classE (905).jpeg
# 1/1 [==============================] - 0s 61ms/step
# Predicted  level_4
# classE (906).jpeg
# 1/1 [==============================] - 0s 50ms/step
# Predicted  level_4
# classE (907).jpeg
# 1/1 [==============================] - 0s 66ms/step
# Predicted  level_4
# classE (908).jpeg
# 1/1 [==============================] - 0s 64ms/step
# Predicted  level_4
# classE (909).jpeg
# 1/1 [==============================] - 0s 53ms/step
# Predicted  level_4
# classE (91).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (910).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (911).jpeg
# 1/1 [==============================] - 0s 52ms/step
# Predicted  level_4
# classE (912).jpeg
# 1/1 [==============================] - 0s 64ms/step
# Predicted  level_4
# classE (913).jpeg
# 1/1 [==============================] - 0s 58ms/step
# Predicted  level_4
# classE (92).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (93).jpeg
# 1/1 [==============================] - 0s 49ms/step
# Predicted  level_4
# classE (94).jpeg
# 1/1 [==============================] - 0s 50ms/step
# Predicted  level_4
# classE (95).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (96).jpeg
# 1/1 [==============================] - 0s 54ms/step
# Predicted  level_4
# classE (97).jpeg
# 1/1 [==============================] - 0s 65ms/step
# Predicted  level_4
# classE (98).jpeg
# 1/1 [==============================] - 0s 63ms/step
# Predicted  level_4
# classE (99).jpeg
# 1/1 [==============================] - 0s 58ms/step
# Predicted  level_4
# Time:  0:13:04.144509
# 4923

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
# Calculate the confusion matrix_1
# print(y_test_1)
# print(y_pred_1)
print(len(y_test_1))
print(len(y_pred_1))
conf_matrix = confusion_matrix(y_test_1,y_pred_1)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(6, 6))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
  for j in range(conf_matrix.shape[1]):
    ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()


# print('Precision: %.3f' % precision_score(y_test_1, y_pred_1,average='micro'))
# print('Recall: %.3f' % recall_score(y_test_1, y_pred_1,average='micro'))
# print('Accuracy: %.3f' % accuracy_score(y_test_1, y_pred_1))
# print('F1 Score: %.3f' % f1_score(y_test_1, y_pred_1,average='micro'))
# Out:
# 4923
# 4923

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import auc 

# Calculate the confusion matrix_1
# print(y_test_1)
# print(y_pred_1)
print(len(y_test_1))
print(len(y_pred_1))
conf_matrix = confusion_matrix(y_test_1,y_pred_1)

#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(6, 8))
ax.matshow(conf_matrix, cmap=plt.cm.summer, alpha=0.7)
for i in range(conf_matrix.shape[0]):
  for j in range(conf_matrix.shape[1]):
    ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
plt.xlabel('Predictions', fontsize=18,fontstyle="italic")
plt.ylabel('Actuals', fontsize=18,fontstyle="italic")
plt.title('Confusion Matrix', fontsize=18,fontstyle="italic")
plt.show()
# Out:
# 4923
# 4923

# %%
FP = conf_matrix.sum(axis=0) - np.diag(conf_matrix)  
FN =conf_matrix.sum(axis=1) - np.diag(conf_matrix)
TP = np.diag(conf_matrix)
TN = conf_matrix.sum() - (FP + FN + TP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# f1-score 
F1 = 2 * (PPV * TPR) / (PPV + TPR)
# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)

print("Sensitivity",TPR)
print("Specificity",TNR)
print("Precision or Positive Predictive Values",PPV)
print("Negative predictive values",NPV)
print("False Positive or Fall Out",FPR)
print("False Negative Rate",FNR)
print("False discovery Rate",FDR)
print("Accuracy",ACC)
print("f1score",F1)
# Out:
# Sensitivity [0.99820628 0.89772727 0.86286286 0.96228448 0.98466594]
# Specificity [0.97190126 0.98508217 0.98012232 0.99098874 0.99825436]
# Precision or Positive Predictive Values [0.91229508 0.93642241 0.91702128 0.96124865 0.99227373]
# Negative predictive values [0.9994599  0.97521902 0.96560382 0.99123686 0.99651481]
# False Positive or Fall Out [0.02809874 0.01491783 0.01987768 0.00901126 0.00174564]
# False Negative Rate [0.00179372 0.10227273 0.13713714 0.03771552 0.01533406]
# False discovery Rate [0.08770492 0.06357759 0.08297872 0.03875135 0.00772627]
# Accuracy [0.97785903 0.96790575 0.95632744 0.9855779  0.99573431]
# f1score [0.95331906 0.91666667 0.8891181  0.96176629 0.9884552 ]

# %%
accuracy = accuracy_score(y_test_1, y_pred_1)
print("Accuracy in test set: %0.1f%% " % (accuracy * 100))
# Out:
# Accuracy in test set: 94.2%

# %%
target= ['level_0', 'level_1', 'level_2', 'level_3', 'level_4']

report = classification_report(y_test_1, y_pred_1, target_names=target)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      level_0       0.91      1.00      0.95      1115
#      level_1       0.94      0.90      0.92       968
#      level_2       0.92      0.86      0.89       999
#      level_3       0.96      0.96      0.96       928
#      level_4       0.99      0.98      0.99       913
#
#     accuracy                           0.94      4923
#    macro avg       0.94      0.94      0.94      4923
# weighted avg       0.94      0.94      0.94      4923

# %%
F1 = 2 * (PPV * TPR) / (PPV + TPR)

# %%
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc, roc_auc_score

data = "/content/drive/MyDrive/eyepacs_aug_test_data/data"
target= ['level_0', 'level_1', 'level_2', 'level_3', 'level_4']

# set plot figure siz
fig,  conf_matrix = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds =roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        conf_matrix.plot(tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
        #conf_matrix.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)


print('ROC AUC score:', multiclass_roc_auc_score(y_test_1, y_pred_1))

conf_matrix.legend()
conf_matrix.set_xlabel('False Positive Rate')
conf_matrix.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9632095691984432

# %%
# sensitivity=[0.99910314, 0.82438017, 0.70570571, 0.8125,0.84556407]
# Specificity= [0.88602941, 0.9630847,  0.96151886, 0.99073842, 0.99700748]
# Precision= [0.71963824, 0.84533898, 0.82359813, 0.95322377, 0.98469388]
# Negative_predictive_rate = [0.9997037,  0.9572757,  0.92771084, 0.95788964, 0.9659338]
# FalsePositive =[0.11397059, 0.0369153,  0.03848114, 0.00926158, 0.00299252]
# FalseNegative_Rate =[0.00089686, 0.17561983, 0.29429429, 0.1875,     0.15443593]
# Falsediscovery_Rate= [0.28036176, 0.15466102, 0.17640187, 0.04677623, 0.01530612]
# Accuracy =[0.91163924, 0.9358115,  0.90960796, 0.95713996, 0.96892139]

# %%
# sensitivity=[0.99910314, 0.82438017, 0.70570571, 0.8125,0.84556407]
# b=0
# c=0
# for i in range (5):
#   b=b+sensitivity[i]
#   #print(b)
# print(b)
# c=b/5
# print("sensitivity is :" c)

# %%
# Specificity= [0.88602941, 0.9630847,  0.96151886, 0.99073842, 0.99700748]
# b=0
# c=0
# for i in range (5):
#   b=b+Specificity[i]
#   #print(b)
# print(b)
# c=b/5
# print("Specificity is :" c)

# %%
# Precision= [0.71963824, 0.84533898, 0.82359813, 0.95322377, 0.98469388]
# b=0
# c=0
# for i in range (5):
#   b=b+Precision[i]
#   #print(b)
# print(b)
# c=b/5
# print("Precision is :" c)

# %%
# Accuracy =[0.91163924, 0.9358115,  0.90960796, 0.95713996, 0.96892139]
# b=0
# c=0
# for i in range (5):
#   b=b+Accuracy[i]
#   #print(b)
# print(b)
# c=b/5
# print("Accuracy is :" c)

# %%
# import matplotlib.pyplot as plt 
# from sklearn.preprocessing import LabelBinarizer
# from sklearn.metrics import roc_curve, auc, roc_auc_score


# target= ['level_0', 'level_1', 'level_2', 'level_3', 'level_4']

# # set plot figure size
# fig, conf_matrix = plt.subplots(1,1, figsize = (12, 8))

# # function for scoring roc auc score for multi-class
# def multiclass_roc_auc_score(y_test_1, y_pred_1, average="macro"):
#     lb = LabelBinarizer()
#     lb.fit(y_test)
#     y_test = lb.transform(y_test_1)
#     y_pred = lb.transform(y_pred_1)

#     for (idx, c_label) in enumerate(target):
#         fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int))
#         conf_matrix.plot(fpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
#         conf_matrix.plot(fpr, fpr, 'b-', label = 'Random Guessing'% (c_label, auc(fpr, tpr)))
#     return roc_auc_score(y_test, y_pred, average=average)


# print('ROC AUC score:', multiclass_roc_auc_score(ds_eye.classes,y_pred_1))

# c_ax.legend()
# c_ax.set_xlabel('False Positive Rate')
# c_ax.set_ylabel('True Positive Rate')
# plt.show()
